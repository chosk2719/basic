# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
mpl.rc('font', family='Malgun Gothic')
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["font.size"] = 14

# %%
import pandas as pd

# %%
ss = pd.read_csv('high_school_2019.csv')
ss
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수
# 0          149         5       143
# 1          228         8       270
# ...

# %%
# 3번

ss['총학생수'] = ss[' 1학년 학생수'] + ss[' 2학년 학생수'] + ss[' 3학년 학생수']
ss
# Out:
#                 지역                 학교명   1학년 학급수   1학년 학생수   2학년 학급수  \
# 0        서울특별시 강남구            국립국악고등학교         5       150         5
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교         8       239         8
# 2        서울특별시 금천구          국립전통예술고등학교         6       182         6
# 3        서울특별시 송파구              가락고등학교        11       282        11
# 4        서울특별시 강동구              강동고등학교         8       210         8
# ...            ...                 ...       ...       ...       ...
# 2393   제주특별자치도 제주시              제주고등학교        11       279        11
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교         8       151         8
# 2395  제주특별자치도 서귀포시              성산고등학교         4        76         5
# 2396   제주특별자치도 제주시           제주외국어고등학교         4        99         4
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교         5       116         5
#
#        2학년 학생수   3학년 학급수   3학년 학생수  총학생수
# 0          149         5       143   442
# 1          228         8       270   737
# ...

# %%
# 4번

sd = ss[[' 1학년 학생수', ' 2학년 학생수', ' 3학년 학생수']].sum()
sd
# Out:
#  1학년 학생수    463400
#  2학년 학생수    444714
#  3학년 학생수    500698
# dtype: int64

# %%
sd.plot.bar(rot=1)
plt.show()

# %%
# 5번

ww = pd.read_csv('population_age_2020.csv')

# %%
we = ww[['지역', '100세 이상', '총인구수']]

# %%
we
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 1     부산     1807   3410925
# 2     대구      694   2432883
# 3     인천      908   2954955
# 4     광주      405   1456121
# 5     대전      339   1473125
# 6     울산      160   1145710
# 7     세종       55    343788
# 8    경기도     4010  13265377
# 9    강원도      803   1539521
# 10  충청북도      541   1598599
# 11  충청남도      885   2120995
# 12  전라북도      817   1815112
# 13  전라남도      822   1861894
# 14  경상북도      960   2658956
# 15  경상남도      739   3358828
# 16   제주도      266    670876

# %%
we = we.sort_values(by=['100세 이상'], ascending=False).reset_index(drop=True)

# %%
we
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 1    경기도     4010  13265377
# 2     부산     1807   3410925
# 3   경상북도      960   2658956
# 4     인천      908   2954955
# 5   충청남도      885   2120995
# 6   전라남도      822   1861894
# 7   전라북도      817   1815112
# 8    강원도      803   1539521
# 9   경상남도      739   3358828
# 10    대구      694   2432883
# 11  충청북도      541   1598599
# 12    광주      405   1456121
# 13    대전      339   1473125
# 14   제주도      266    670876
# 15    울산      160   1145710
# 16    세종       55    343788
