# %%
from urllib import request as url
import re
from collections import Counter
def wordcount(url_input):
    with url.urlopen(url_input) as doc:
        html = doc.read().decode()
        words = re.findall(r"\w+", html)
        
        frequency = Counter(words).most_common()
        
        return frequency

# %%
if __name__=='__main__':
    result = wordcount('https://www.daum.net/')
    print(result)
# Out:
# [('class', 1086), ('data', 864), ('span', 779), ('tiara', 724), ('0', 646), ('height', 545), ('position', 544), ('background', 524), ('a', 473), ('net', 423), ('width', 422), ('top', 366), ('li', 361), ('action', 297), ('div', 293), ('layer', 292), ('left', 279), ('daumcdn', 254), ('href', 250), ('name', 246), ('https', 244), ('hidden', 240), ('margin', 236), ('color', 218), ('padding', 216), ('overflow', 206), ('font', 197), ('t1', 192), ('right', 172), ('display', 169), ('daum', 166), ('os_mac', 166), ('id', 162), ('text', 158), ('line', 155), ('size', 154), ('block', 139), ('png', 137), ('src', 132), ('strong', 129), ('images', 128), ('daumtop_deco', 123), ('1px', 118), ('absolute', 116), ('float', 116), ('frame_g', 113), ('url', 110), ('img', 107), ('suggestBox', 100), ('keyboard_layer', 89), ('link_tit', 84), ('bottom', 81), ('today_layer', 81), ('img_thumb', 80), ('12px', 79), ('dd', 77), ('none', 77), ('relative', 77), ('v', 76), ('alt', 75), ('border', 74), ('screen_out', 74), ('align', 72), ('ir_wa', 72), ('20px', 70), ('16px', 69), ('view_slide', 68), ('13px', 67), ('amp', 67), ('EC', 67), ('com', 67), ('kind', 66), ('ClickContent', 66), ('ordnum', 66), ('thumb', 66), ('tit_item', 65), ('2017', 64), ('link_thumb', 63), ('true', 62), ('op', 62), ('cont_item', 61), ('kakao', 61), ('11px', 60), ('14px', 60), ('100', 59), ('30px', 58), ('suggest_exact', 58), ('http', 57), ('search', 57), ('link_item', 57), ('aria', 57), ('transform', 56), ('ico_pctop', 55), ('solid', 54), ('2px', 54), ('panel_bloc', 54), ('img2', 54), ('fname', 54), ('h3', 53), ('1', 53), ('hover', 52), ('em', 51), ('10px', 51), ('10', 50), ('repeat', 49), ('group_keyboard', 49), ('39', 48), ('news', 47), ('button', 46), ('thumb_g', 46), ('15px', 46), ('fff', 45), ('decoration', 45), ('index', 45), ('info_today', 45), ('ul', 44), ('8px', 44), ('title', 43), ('vertical', 43), ('inline', 43), ('space', 43), ('소재', 43), ('white', 42), ('888', 42), ('image', 41), ('together', 41), ('indent', 40), ('txt_pctop', 40), ('18px', 40), ('94', 40), ('클릭', 40), ('GNB_서비스_더보기', 40), ('fst', 39), ('no', 38), ('nowrap', 38), ('target', 38), ('레이어_서비스', 38), ('hamny', 38), ('weight', 37), ('4px', 37), ('7px', 37), ('link_svc', 37), ('relay_special', 37), ('type', 36), ('z', 36), ('9px', 36), ('_blank', 35), ('p', 34), ('family', 34), ('sans', 34), ('serif', 34), ('auto', 34), ('36px', 34), ('60px', 34), ('60', 34), ('jpg', 34), ('letter', 33), ('spacing', 33), ('9999px', 33), ('3px', 33), ('default', 33), ('gallery', 33), ('ellipsis', 32), ('img_weather', 31), ('5px', 30), ('origin_item', 30), ('translateY', 30), ('EB', 30), ('154', 30), ('202006', 30), ('normal', 29), ('hide', 29), ('transition', 29), ('max', 29), ('view_photo', 29), ('ED', 29), ('q', 28), ('foot_daum', 28), ('6px', 28), ('100px', 28), ('wrap_tabcont', 28), ('list_ranking', 28), ('오늘의', 28), ('txt', 28), ('h2', 27), ('box_channel', 27), ('날씨', 27), ('dt', 26), ('40px', 26), ('on', 26), ('tit_tabcont', 26), ('media', 26), ('viewer', 26), ('118eff', 25), ('28px', 25), ('btn_keyboard', 25), ('22px', 25), ('ico_degree', 25), ('list_relay', 25), ('rtn', 25), ('카카오', 25), ('dl', 24), ('120px', 24), ('17px', 24), ('night', 24), ('service_layer', 24), ('txt_temper', 24), ('word', 24), ('tot', 24), ('w', 24), ('DA', 24), ('cafe', 24), ('tv', 24), ('ico_vert', 23), ('page_pctop', 23), ('login_my', 23), ('영상', 23), ('45px', 22), ('ico_ws', 22), ('95', 22), ('ececec', 21), ('80px', 21), ('txt_part', 21), ('84', 21), ('포토_데이터', 21), ('center', 20), ('sort_service', 20), ('break', 20), ('ad', 20), ('2', 20), ('C', 20), ('head_daum', 19), ('200px', 19), ('btn_page', 19), ('154px', 19), ('list_story', 19), ('box_photo', 19), ('tabindex', 19), ('imp_id', 19), ('custom', 19), ('c_id', 19), ('script', 18), ('style', 18), ('222', 18), ('shortcut_g', 18), ('num_pctop', 18), ('300px', 18), ('19px', 18), ('555', 18), ('ico_video', 18), ('list_thumb', 18), ('cover_g', 18), ('relay_general', 18), ('box_chextra', 18), ('9C', 18) ...

# %%
def wordcount(url_input):
    with url.urlopen(url_input) as doc:
        html = doc.read().decode()
        words = re.findall(r"\w+", html)
        
#         word = set(words)

        frequency = Counter(words).most_common()
        
        sorted(frequency, key = lambda frequency: frequency[1])
        
        return frequency

# %%
if __name__=='__main__':
    result = wordcount('https://www.daum.net/')
    print(result)
# Out:
# [('class', 1058), ('data', 840), ('span', 751), ('tiara', 681), ('0', 646), ('position', 544), ('height', 540), ('background', 524), ('a', 449), ('net', 436), ('width', 421), ('top', 366), ('li', 337), ('div', 301), ('left', 278), ('layer', 278), ('action', 274), ('daumcdn', 272), ('hidden', 240), ('href', 238), ('margin', 236), ('name', 234), ('https', 226), ('color', 218), ('padding', 216), ('t1', 206), ('overflow', 206), ('font', 197), ('display', 175), ('daum', 173), ('right', 171), ('os_mac', 166), ('id', 163), ('text', 157), ('line', 155), ('size', 154), ('src', 140), ('block', 139), ('png', 139), ('strong', 133), ('daumtop_deco', 132), ('images', 131), ('1px', 118), ('frame_g', 118), ('absolute', 116), ('float', 116), ('url', 110), ('img', 107), ('suggestBox', 100), ('keyboard_layer', 89), ('link_tit', 83), ('bottom', 81), ('today_layer', 81), ('img_thumb', 79), ('12px', 79), ('amp', 79), ('dd', 77), ('none', 77), ('relative', 77), ('op', 76), ('v', 76), ('border', 74), ('screen_out', 73), ('align', 72), ('ir_wa', 72), ('20px', 70), ('alt', 70), ('thumb', 70), ('16px', 69), ('view_slide', 68), ('13px', 67), ('cont_item', 66), ('tit_item', 64), ('link_thumb', 63), ('true', 62), ('link_item', 61), ('com', 61), ('100', 60), ('11px', 60), ('14px', 60), ('2017', 60), ('30px', 58), ('suggest_exact', 58), ('img2', 58), ('fname', 58), ('search', 57), ('aria', 57), ('http', 56), ('ico_pctop', 56), ('transform', 56), ('kind', 55), ('ClickContent', 55), ('solid', 54), ('2px', 54), ('panel_bloc', 54), ('hover', 52), ('h3', 51), ('1', 51), ('10px', 51), ('10', 51), ('thumb_g', 50), ('ordnum', 50), ('em', 49), ('repeat', 49), ('group_keyboard', 49), ('news', 47), ('button', 46), ('15px', 46), ('default', 46), ('EC', 46), ('fff', 45), ('decoration', 45), ('index', 45), ('info_today', 45), ('8px', 44), ('kakao', 44), ('jpg', 44), ('vertical', 43), ('inline', 43), ('space', 43), ('title', 42), ('white', 42), ('888', 42), ('target', 42), ('hamny', 42), ('image', 41), ('ul', 40), ('indent', 40), ('txt_pctop', 40), ('18px', 40), ('클릭', 40), ('GNB_서비스_더보기', 40), ('39', 40), ('_blank', 39), ('no', 38), ('nowrap', 38), ('fst', 38), ('94', 38), ('레이어_서비스', 38), ('weight', 37), ('4px', 37), ('7px', 37), ('link_svc', 37), ('relay_special', 37), ('type', 36), ('p', 36), ('z', 36), ('9px', 36), ('family', 34), ('sans', 34), ('serif', 34), ('auto', 34), ('36px', 34), ('60px', 34), ('60', 34), ('154', 34), ('letter', 33), ('spacing', 33), ('9999px', 33), ('3px', 33), ('gallery', 33), ('ellipsis', 32), ('origin_item', 32), ('소재', 32), ('202006', 32), ('img_weather', 31), ('5px', 30), ('media', 30), ('translateY', 30), ('normal', 29), ('hide', 29), ('transition', 29), ('max', 29), ('view_photo', 29), ('오늘의', 29), ('q', 28), ('foot_daum', 28), ('6px', 28), ('100px', 28), ('wrap_tabcont', 28), ('h2', 27), ('list_ranking', 27), ('game', 27), ('날씨', 27), ('dt', 26), ('40px', 26), ('on', 26), ('tit_tabcont', 26), ('viewer', 26), ('118eff', 25), ('28px', 25), ('btn_keyboard', 25), ('22px', 25), ('ico_degree', 25), ('list_relay', 25), ('box_channel', 25), ('rtn', 25), ('EB', 25), ('카카오', 25), ('dl', 24), ('120px', 24), ('17px', 24), ('night', 24), ('service_layer', 24), ('txt_temper', 24), ('word', 24), ('영상', 24), ('tot', 24), ('w', 24), ('DA', 24), ('page_pctop', 23), ('login_my', 23), ('ico_vert', 22), ('45px', 22), ('ico_ws', 22), ('ececec', 21), ('80px', 21), ('txt_part', 21), ('imp_id', 21), ('custom', 21), ('c_id', 21), ('포토_데이터', 21), ('center', 20), ('sort_service', 20), ('break', 20), ('ad', 20), ('C', 20), ('head_daum', 19), ('200px', 19), ('btn_page', 19), ('154px', 19), ('list_story', 19), ('box_infobnr', 19), ('box_photo', 19), ('tabindex', 19), ('tv', 19), ('script', 18), ('style', 18), ('222', 18), ('shortcut_g', 18), ('300px', 18), ('19px', 18), ('555', 18), ('ico_video', 18), ('list_thumb', 18), ('cover_g', 18), ('relay_general', 18), ('box_chextra', 18), ('txt', 18), ('운영_하단', 18), ('26px', 17), ('24px', 17), ('list_mainsvc', 17), ('btn_ne ...
