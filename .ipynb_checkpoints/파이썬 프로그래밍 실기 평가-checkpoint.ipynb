# %%
# 1번

line = int(input('숫자를 입력하시오 :'))
# Out:
# 숫자를 입력하시오 :4

# %%
for star in range(1, line+1):
    print(' '*(line - star) + '*'*(2*star-1),
          ('  '*(line - star) + '*'*(2*star-1)))
# Out:
#    *       *
#   ***     ***
#  *****   *****
# ******* *******

# %%
import numpy as np

# %%
import matplotlib.pylab as plt

# %%
x = np.linspace(-2, 2, 600)
plt.plot(x, np.tanh(x))
plt.xlabel('x')
plt.ylabel('y')
#plt.axis('tight')
plt.show()

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
import requests
import pandas as pd

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
req = requests.get('https://www.melon.com/chart/month/index.htm', headers = header) ## 주간 차트를 크롤링 할 것임
html = req.text
parse = BeautifulSoup(html, 'html.parser')
soup = BeautifulSoup(html, 'html.parser')

# %%
parse = BeautifulSoup(html, 'html.parser')

# %%
result = soup.find(class_='service_list_song type02 d_song_list')
result
# Out:
# <div class="service_list_song type02 d_song_list">
# <h3 class="none"></h3>
# <!-- 곡리스트 테이블 -->
# <div class="wrap_btn_tb top">
# <button class="button_rbox" onclick="playChart();" title="TOP 100 듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt">전체 듣기</span></button>
# <button class="button_rbox" onclick="melon.play.playFormSong('19041401','frm');" title="선택된 곡 듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt">듣기</span></button>
# <button class="button_rbox" onclick="melon.play.addFormPlayList('frm');" title="선택된 곡 담기" type="button"><span class="button_icons type02 scrap"></span><span class="cnt">담기</span></button>
# <button class="button_rbox" onclick="melon.buy.goBuyProduct('frm','','3C0001','input_check','0','19041401');" title="선택된 곡 다운로드" type="button"><span class="button_icons type02 download"></span><span class="cnt">다운</span></button>
# ...

# %%
import requests
from bs4 import BeautifulSoup
 
if __name__ == "__main__":
    RANK = 100 ## 멜론 차트 순위가 1 ~ 100위까지 있음
 
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
    req = requests.get('https://www.melon.com/chart/month/index.htm', headers = header) ## 주간 차트를 크롤링 할 것임
    html = req.text
    parse = BeautifulSoup(html, 'html.parser')
 
    titles = parse.find_all("div", {"class": "ellipsis rank01"}) 
    singers = parse.find_all("div", {"class": "ellipsis rank02"}) 
    albums = parse.find_all("div",{"class": "ellipsis rank03"})
 
    title = []
    singer = []
    album = []
 
    for t in titles:
        title.append(t.find('a').text)
 
    for s in singers:
        singer.append(s.find('span', {"class": "checkEllipsis"}).text)

    for a in albums:
        album.append(a.find('a').text)
        
 
    for i in range(RANK):
        print('%3d위: [ %s ] %s - %s'%(i+1, title[i], album[i], singer[i]))
# Out:
#   1위: [ 에잇(Prod.&Feat. SUGA of BTS) ] 에잇 - 아이유
#   2위: [ 아로하 ] 슬기로운 의사생활 OST Part 3 - 조정석
#   3위: [ 살짝 설렜어 (Nonstop) ] NONSTOP - 오마이걸
#   4위: [ 나비와 고양이 (feat.백현 (BAEKHYUN)) ] 사춘기집Ⅱ 꽃 본 나비 - 볼빨간사춘기
#   5위: [ 시작 ] 이태원 클라쓰 OST Part.2 - 가호 (Gaho)
#   6위: [ 처음처럼 ] CEREMONIA - 엠씨더맥스 (M.C the MAX)
#   7위: [ 덤더럼(Dumhdurum) ] LOOK - Apink (에이핑크)
#   8위: [ 좋은 사람 있으면 소개시켜줘 ] 슬기로운 의사생활 OST Part 2 - 조이 (JOY)
#   9위: [ 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 ] 멜로가 체질 OST Part 3 - 장범준
#  10위: [ Happy ] Happy - 태연 (TAEYEON)
#  11위: [ ON ] MAP OF THE SOUL : 7 - 방탄소년단
#  12위: [ 아무노래 ] 아무노래 - 지코 (ZICO)
#  13위: [ METEOR ] Boyhood - 창모 (CHANGMO)
#  14위: [ Blueming ] Love poem - 아이유
#  15위: [ 우리 만남이 ] 정규 2집 '마음, 둘' - 폴킴
#  16위: [ 그때 그 아인 ] 이태원 클라쓰 OST Part.6 - 김필
#  17위: [ 돌덩이 ] 이태원 클라쓰 OST Part.3 - 하현우 (국카스텐)
#  18위: [ 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) ] MAP OF THE SOUL : PERSONA - 방탄소년단
#  19위: [ Dance Monkey ] The Kids Are Coming - Tones And I
#  20위: [ 사랑하게 될 줄 알았어 ] 슬기로운 의사생활 OST Part 11 - 전미도
# ...

# %%
        print('%3d위: %s [ %s ] - %s'%(i+1, title[i], album[i], singer[i]))
        print('%s, - %s, [ %s ], %3d위'%(title[i], singer[i], album[i], i+1))
# Out:
# 100위: 나쁜 놈 [ Off The Record ] - 벤
# 나쁜 놈, - 벤, [ Off The Record ], 100위

# %%
rank = soup.find(class_='rank')
rank
# Out:
# <span class="rank">순위</span>

# %%
df = pd.DataFrame({'순위' : '%3d위'%(i+1), '제목' : title, '엘범' : album, '가수' : singer})
df[0:10]
# Out:
#      순위                            제목                    엘범  \
# 0  100위   에잇(Prod.&Feat. SUGA of BTS)                    에잇
# 1  100위                           아로하  슬기로운 의사생활 OST Part 3
# 2  100위              살짝 설렜어 (Nonstop)               NONSTOP
# 3  100위  나비와 고양이 (feat.백현 (BAEKHYUN))          사춘기집Ⅱ 꽃 본 나비
# 4  100위                            시작    이태원 클라쓰 OST Part.2
# 5  100위                          처음처럼             CEREMONIA
# 6  100위                덤더럼(Dumhdurum)                  LOOK
# 7  100위               좋은 사람 있으면 소개시켜줘  슬기로운 의사생활 OST Part 2
# 8  100위      흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야     멜로가 체질 OST Part 3
# 9  100위                         Happy                 Happy
#
#                     가수
# 0                  아이유
# 1                  조정석
# 2                 오마이걸
# 3               볼빨간사춘기
# 4            가호 (Gaho)
# 5  엠씨더맥스 (M.C the MAX)
# 6         Apink (에이핑크)
# 7             조이 (JOY)
# 8                  장범준
# 9         태연 (TAEYEON)

# %%
url_base = 'https://www.melon.com'
url_sub = '/chart/month/index.htm'
html = urlopen(url_base + url_sub)
soup = BeautifulSoup(html, 'html.parser')
